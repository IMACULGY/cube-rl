# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# plot function
def plotarr(arr):
    plt.xlabel('iteration')
    plt.ylabel('loss')
    plt.plot(arr)
    plt.show()

# %% [markdown]
# ## Approximate policy iteration

# %% [markdown]
# Plot loss function

# %%
# get numpy array
losses = np.load('api_loss.npy')
plotarr(losses)

# %% [markdown]
# ## Deep QN

# %% [markdown]
# Plot loss function
